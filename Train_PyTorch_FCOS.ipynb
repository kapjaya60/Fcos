# %% [markdown]
# <a href="https://colab.research.google.com/github/kapjaya60/SSD/blob/main/Train_PyTorch_SSD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os
from PIL import Image, ImageDraw
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision import transforms as T
from torchvision.models.detection import fcos_resnet50_fpn
from sklearn.metrics import precision_recall_fscore_support
from torchvision.ops import box_iou

# %%
# Download the file from the specified URL
# !wget "https://app.roboflow.com/ds/3H7cxrKYsz?key=HVaPUzZi2o" -O dataset.zip

# Unzip the downloaded file
# !unzip dataset.zip > /dev/null
# Out:
# --2024-12-31 15:52:19--  https://app.roboflow.com/ds/3H7cxrKYsz?key=HVaPUzZi2o
# Resolving app.roboflow.com (app.roboflow.com)... 151.101.1.195, 151.101.65.195, 2620:0:890::100
# Connecting to app.roboflow.com (app.roboflow.com)|151.101.1.195|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/roboflow-platform-regional-exports/zLz9rQfSVg8cZGmLT3uV/BFD1UH2Tp5ibiZQSnXue/11/tensorflow.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20241231%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20241231T155219Z&X-Goog-Expires=900&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# --2024-12-31 15:52:19--  https://storage.googleapis.com/roboflow-platform-regional-exports/zLz9rQfSVg8cZGmLT3uV/BFD1UH2Tp5ibiZQSnXue/11/tensorflow.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20241231%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20241231T155219Z&X-Goog-Expires=900&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.141.207, 74.125.137.207, 142.250.101.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.141.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14690951 (14M) [application/zip]
# Saving to: ‘dataset.zip’
#
# dataset.zip         100%[===================>]  14.01M  28.5MB/s    in 0.5s
#
# 2024-12-31 15:52:20 (28.5 MB/s) - ‘dataset.zip’ saved [14690951/14690951]

# %%
# Load CSV and prepare datasets
train = pd.read_csv('/content/train/_annotations.csv')
valid = pd.read_csv('/content/valid/_annotations.csv')

# %%
train_unique_imgs = train.filename.unique()
valid_unique_imgs = valid.filename.unique()

# %%
class CustDat(Dataset):
    def __init__(self, df, unique_imgs, root_dir, transform=None):
        self.df = df
        self.unique_imgs = unique_imgs
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.unique_imgs)

    def __getitem__(self, idx):
        image_name = self.unique_imgs[idx]
        # Filter bounding boxes for the current image
        boxes_df = self.df[self.df.filename == image_name][['xmin', 'ymin', 'xmax', 'ymax']]
        boxes = boxes_df.values.astype("float")  # Convert bounding box coordinates to float
        img_path = os.path.join(self.root_dir, image_name)
        img = Image.open(img_path).convert('RGB')  # Open the image

        # Assuming a single class for all boxes (can be adjusted as needed)
        labels = torch.ones((boxes.shape[0]), dtype=torch.int64)

        # Prepare the target dictionary
        target = {
            'boxes': torch.tensor(boxes, dtype=torch.float32),
            'labels': labels
        }

        # Apply any transformations to the image
        if self.transform:
            img = self.transform(img)

        return img, target

# %%
# Create datasets
train_dataset = CustDat(df=train, unique_imgs=train_unique_imgs, root_dir='/content/train',
                        transform=T.ToTensor())
valid_dataset = CustDat(df=valid, unique_imgs=valid_unique_imgs, root_dir='/content/valid',
                        transform=T.ToTensor())

# Create dataloaders
train_dl = DataLoader(train_dataset, batch_size=4, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))
valid_dl = DataLoader(valid_dataset, batch_size=1, shuffle=False, collate_fn=lambda x: tuple(zip(*x)))

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
model = fcos_resnet50_fpn(weights="DEFAULT")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:01<00:00, 153MB/s]

# %%
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.0025, momentum=0.9, weight_decay=0.0005)

# Learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)
num_epochs = 100

# %%
save_dir = "fcos_model"
os.makedirs(save_dir, exist_ok=True)  # Create the directory if it doesn't exist

# %%
model.to(device)

for epoch in range(num_epochs):
    # TRAINING
    model.train()
    epoch_loss = 0
    for imgs, targets in train_dl:
        imgs = [img.to(device) for img in imgs]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        # Forward pass
        loss_dict = model(imgs, targets)
        loss = sum(v for v in loss_dict.values())

        # Accumulate epoch loss
        epoch_loss += loss.cpu().detach().numpy()

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print(f"Epoch [{epoch + 1}/{num_epochs}] Loss: {epoch_loss:.4f}")

    # Save model every 10 epochs
    if (epoch + 1) % 10 == 0:
        save_path = os.path.join(save_dir, f"fcos_epoch_{epoch + 1}.pth")
        torch.save(model.state_dict(), save_path)
        print(f"Model saved at {save_path}")


    model.eval()  # Set the model to evaluation mode
    y_true = []
    y_pred = []

    iou_threshold = 0.5

    with torch.no_grad():
        for imgs, targets in valid_dl:
            imgs = [img.to(device) for img in imgs]
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

            outputs = model(imgs)  # Predictions from the model

            # Validate predictions
            for i, output in enumerate(outputs):
                pred_boxes = output["boxes"].cpu()
                pred_labels = output["labels"].cpu()
                gt_boxes = targets[i]["boxes"].cpu()
                gt_labels = targets[i]["labels"].cpu()

                # IoU matching between ground truths and predictions
                if len(gt_boxes) > 0 and len(pred_boxes) > 0:
                    iou_matrix = box_iou(gt_boxes, pred_boxes)

                    for gt_idx, gt_label in enumerate(gt_labels):
                        max_iou, pred_idx = iou_matrix[gt_idx].max(0)  # Best match for each GT box
                        if max_iou > iou_threshold:
                            y_true.append(gt_label.item())
                            y_pred.append(pred_labels[pred_idx].item())
                        else:
                            # False negative for unmatched ground truths
                            y_true.append(gt_label.item())
                            y_pred.append(0)  # Assume unmatched predictions as class 0

                    # False positives for unmatched predictions
                    matched_pred_indices = iou_matrix.argmax(0)
                    unmatched_preds = set(range(len(pred_boxes))) - set(matched_pred_indices.tolist())
                    for pred_idx in unmatched_preds:
                        y_true.append(0)  # No ground truth
                        y_pred.append(pred_labels[pred_idx].item())
                else:
                    # If no predictions or no ground truths, handle accordingly
                    y_true.extend(gt_labels.tolist())
                    y_pred.extend([0] * len(gt_labels))  # All are unmatched (false negatives)

                    y_true.extend([0] * len(pred_boxes))  # All predictions are unmatched (false positives)
                    y_pred.extend(pred_labels.tolist())

    # Calculate validation metrics
    precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average="weighted", zero_division=0)

    # Print validation metrics
    print(f"Validation Metrics:")
    print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, F1-Score: {f1:.4f}")

from google.colab import files
files.download('/content/fcos_model/fcos_epoch_100.pth')
# Out:
# Epoch [1/100] Loss: 48.5726
# Validation - Epoch [1/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [2/100] Loss: 24.1583
# Validation - Epoch [2/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [3/100] Loss: 20.3566
# Validation - Epoch [3/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [4/100] Loss: 17.8091
# Validation - Epoch [4/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [5/100] Loss: 16.2551
# Validation - Epoch [5/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [6/100] Loss: 15.1979
# Validation - Epoch [6/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [7/100] Loss: 14.6852
# Validation - Epoch [7/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [8/100] Loss: 13.6862
# Validation - Epoch [8/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [9/100] Loss: 13.0521
# Validation - Epoch [9/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [10/100] Loss: 12.4944
# Model saved at faster_rcnn_model/faster_rcnn_epoch_10.pth
# Validation - Epoch [10/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [11/100] Loss: 12.4160
# Validation - Epoch [11/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [12/100] Loss: 11.6300
# Validation - Epoch [12/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [13/100] Loss: 11.2355
# Validation - Epoch [13/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [14/100] Loss: 10.9098
# Validation - Epoch [14/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [15/100] Loss: 10.5260
# Validation - Epoch [15/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [16/100] Loss: 9.9832
# Validation - Epoch [16/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [17/100] Loss: 9.9957
# Validation - Epoch [17/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [18/100] Loss: 9.6028
# Validation - Epoch [18/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [19/100] Loss: 9.2010
# Validation - Epoch [19/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [20/100] Loss: 9.2551
# Model saved at faster_rcnn_model/faster_rcnn_epoch_20.pth
# Validation - Epoch [20/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [21/100] Loss: 9.0115
# Validation - Epoch [21/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [22/100] Loss: 8.5986
# Validation - Epoch [22/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [23/100] Loss: 8.3263
# Validation - Epoch [23/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [24/100] Loss: 8.2713
# Validation - Epoch [24/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [25/100] Loss: 7.9191
# Validation - Epoch [25/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [26/100] Loss: 7.8153
# Validation - Epoch [26/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [27/100] Loss: 7.8700
# Validation - Epoch [27/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [28/100] Loss: 7.5909
# Validation - Epoch [28/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [29/100] Loss: 7.3804
# Validation - Epoch [29/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [30/100] Loss: 7.1703
# Model saved at faster_rcnn_model/faster_rcnn_epoch_30.pth
# Validation - Epoch [30/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [31/100] Loss: 6.9020
# Validation - Epoch [31/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [32/100] Loss: 6.7927
# Validation - Epoch [32/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [33/100] Loss: 6.6002
# Validation - Epoch [33/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [34/100] Loss: 6.3449
# Validation - Epoch [34/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [35/100] Loss: 6.6881
# Validation - Epoch [35/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [36/100] Loss: 6.4559
# Validation - Epoch [36/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [37/100] Loss: 6.0975
# Validation - Epoch [37/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [38/100] Loss: 6.0186
# Validation - Epoch [38/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [39/100] Loss: 5.8687
# Validation - Epoch [39/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [40/100] Loss: 5.7530
# Model saved at faster_rcnn_model/faster_rcnn_epoch_40.pth
# Validation - Epoch [40/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [41/100] Loss: 5.7007
# Validation - Epoch [41/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [42/100] Loss: 5.6444
# Validation - Epoch [42/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [43/100] Loss: 5.5251
# Validation - Epoch [43/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [44/100] Loss: 5.4572
# Validation - Epoch [44/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [45/100] Loss: 5.3641
# Validation - Epoch [45/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [46/100] Loss: 5.1865
# Validation - Epoch [46/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [47/100] Loss: 5.1481
# Validation - Epoch [47/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [48/100] Loss: 5.0910
# Validation - Epoch [48/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [49/100] Loss: 4.9744
# Validation - Epoch [49/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [50/100] Loss: 4.9504
# Model saved at faster_rcnn_model/faster_rcnn_epoch_50.pth
# Validation - Epoch [50/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [51/100] Loss: 4.8552
# Validation - Epoch [51/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [52/100] Loss: 4.9286
# Validation - Epoch [52/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [53/100] Loss: 4.8550
# Validation - Epoch [53/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [54/100] Loss: 4.7152
# Validation - Epoch [54/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [55/100] Loss: 4.5885
# Validation - Epoch [55/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [56/100] Loss: 4.4378
# Validation - Epoch [56/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [57/100] Loss: 4.2600
# Validation - Epoch [57/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [58/100] Loss: 4.2675
# Validation - Epoch [58/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [59/100] Loss: 4.2635
# Validation - Epoch [59/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [60/100] Loss: 4.1278
# Model saved at faster_rcnn_model/faster_rcnn_epoch_60.pth
# Validation - Epoch [60/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [61/100] Loss: 4.1441
# Validation - Epoch [61/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [62/100] Loss: 4.0794
# Validation - Epoch [62/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [63/100] Loss: 3.9680
# Validation - Epoch [63/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [64/100] Loss: 3.9005
# Validation - Epoch [64/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [65/100] Loss: 3.8430
# Validation - Epoch [65/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [66/100] Loss: 3.8392
# Validation - Epoch [66/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [67/100] Loss: 3.8282
# Validation - Epoch [67/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [68/100] Loss: 3.9810
# Validation - Epoch [68/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [69/100] Loss: 3.8831
# Validation - Epoch [69/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [70/100] Loss: 3.7350
# Model saved at faster_rcnn_model/faster_rcnn_epoch_70.pth
# Validation - Epoch [70/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [71/100] Loss: 4.1026
# Validation - Epoch [71/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [72/100] Loss: 3.8302
# Validation - Epoch [72/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [73/100] Loss: 3.7130
# Validation - Epoch [73/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [74/100] Loss: 3.5283
# Validation - Epoch [74/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [75/100] Loss: 3.4181
# Validation - Epoch [75/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [76/100] Loss: 3.2914
# Validation - Epoch [76/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [77/100] Loss: 3.3021
# Validation - Epoch [77/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [78/100] Loss: 3.3296
# Validation - Epoch [78/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [79/100] Loss: 3.4528
# Validation - Epoch [79/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [80/100] Loss: 3.3232
# Model saved at faster_rcnn_model/faster_rcnn_epoch_80.pth
# Validation - Epoch [80/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [81/100] Loss: 3.5628
# Validation - Epoch [81/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [82/100] Loss: 3.2390
# Validation - Epoch [82/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [83/100] Loss: 3.1987
# Validation - Epoch [83/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [84/100] Loss: 3.0110
# Validation - Epoch [84/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [85/100] Loss: 3.1345
# Validation - Epoch [85/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [86/100] Loss: 3.0737
# Validation - Epoch [86/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [87/100] Loss: 3.1034
# Validation - Epoch [87/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [88/100] Loss: 3.1036
# Validation - Epoch [88/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [89/100] Loss: 2.9622
# Validation - Epoch [89/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [90/100] Loss: 3.0261
# Model saved at faster_rcnn_model/faster_rcnn_epoch_90.pth
# Validation - Epoch [90/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [91/100] Loss: 3.0447
# Validation - Epoch [91/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [92/100] Loss: 2.9314
# Validation - Epoch [92/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [93/100] Loss: 2.8456
# Validation - Epoch [93/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [94/100] Loss: 2.8562
# Validation - Epoch [94/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [95/100] Loss: 2.8417
# Validation - Epoch [95/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [96/100] Loss: 2.7718
# Validation - Epoch [96/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [97/100] Loss: 2.6554
# Validation - Epoch [97/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [98/100] Loss: 2.6008
# Validation - Epoch [98/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [99/100] Loss: 2.6376
# Validation - Epoch [99/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
# Epoch [100/100] Loss: 2.6176
# Model saved at faster_rcnn_model/faster_rcnn_epoch_100.pth
# Validation - Epoch [100/100]:
# Precision: 1.0000, Recall: 1.0000, F1-Score: 1.0000
